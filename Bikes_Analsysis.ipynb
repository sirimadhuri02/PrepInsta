# %% [markdown]
# <a href="https://colab.research.google.com/github/sirimadhuri02/PrepInsta/blob/Analysis_Practice/Bikes_Analsysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Used_Bikes.csv")

# %%
data
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
data.shape
# Out:
# (32648, 8)

# %%
df = pd.DataFrame(data)

# %%
data.tail
# Out:
# <bound method NDFrame.tail of                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
data[5:0:-1]
# Out:
#                               bike_name     price       city  kms_driven  \
# 5                      Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
#
#          owner  age  power          brand
# 5  First Owner  6.0  150.0         Yamaha
# 4  First Owner  3.0  150.0         Yamaha
# 3  First Owner  4.0  180.0            TVS
# 2  First Owner  8.0  675.0        Triumph
# 1  First Owner  4.0  350.0  Royal Enfield

# %%
data[5:-1:-1]
# Out:
# Empty DataFrame
# Columns: [bike_name, price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
df[4:1:-1]
# Out:
#                               bike_name     price       city  kms_driven  \
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
#
#          owner  age  power    brand
# 4  First Owner  3.0  150.0   Yamaha
# 3  First Owner  4.0  180.0      TVS
# 2  First Owner  8.0  675.0  Triumph

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.brand
# Out:
# 0                  TVS
# 1        Royal Enfield
# 2              Triumph
# 3                  TVS
# 4               Yamaha
#              ...
# 32643             Hero
# 32644              TVS
# 32645            Bajaj
# 32646             Hero
# 32647            Bajaj
# Name: brand, Length: 32648, dtype: object

# %%
df.brand.unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df['price'].max()
# Out:
# 1900000.0

# %%
df['price'].min()
# Out:
# 4400.0

# %%
df.describe()
# Out:
#               price     kms_driven           age         power
# count  3.264800e+04   32648.000000  32648.000000  32648.000000
# mean   6.829542e+04   26344.625184      8.048211    213.511302
# std    9.071860e+04   22208.527695      4.031700    134.428868
# min    4.400000e+03       1.000000      1.000000    100.000000
# 25%    2.500000e+04   12000.000000      5.000000    150.000000
# 50%    4.300000e+04   20373.000000      7.000000    150.000000
# 75%    8.000000e+04   35000.000000     10.000000    220.000000
# max    1.900000e+06  750000.000000     63.000000   1800.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df[df.age>20]
# Out:
#                           bike_name     price                city  kms_driven  \
# 334     Royal Enfield Bullet 350 cc  125000.0           Hyderabad     16500.0
# 1219                  Hero CD 100SS   25500.0              Kharar     10000.0
# 1334        TVS Suzuki Shogun 110cc  100000.0           Bangalore     66000.0
# 1363        TVS Suzuki Shogun 110cc  100000.0           Bangalore     66000.0
# 1519              Rajdoot GTX 175cc   75000.0               Delhi       500.0
# 1976   Royal Enfield Standard 350cc  250000.0             Chennai      1400.0
# 2146    Royal Enfield‎ Bullet 350cc   85990.0              Raipur     19000.0
# 2265     Yamaha RX135 135cc 4-Speed   85000.0              Mumbai       300.0
# 2299                  Hero CD 100SS   10000.0             Chennai    646000.0
# 2322                  Hero CD 100SS   10000.0             Chennai    646000.0
# 2978    Royal Enfield‎ Bullet 350cc   95000.0           Bangalore     50000.0
# ...

# %%
df[df.price == df.price.max()]
# Out:
#                        bike_name      price     city  kms_driven        owner  \
# 367  Indian Chief Classic 1800cc  1900000.0  Chennai      1700.0  First Owner
#
#      age   power   brand
# 367  6.0  1800.0  Indian

# %%
df1 = df.set_index('price')

# %%
df1
# Out:
#                                      bike_name       city  kms_driven  \
# price
# 35000.0     TVS Star City Plus Dual Tone 110cc  Ahmedabad     17654.0
# 119900.0           Royal Enfield Classic 350cc      Delhi     11000.0
# 600000.0                  Triumph Daytona 675R      Delhi       110.0
# 65000.0                   TVS Apache RTR 180cc  Bangalore     16329.0
# 80000.0   Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore     10000.0
# ...                                        ...        ...         ...
# 39000.0                 Hero Passion Pro 100cc      Delhi     22000.0
# 30000.0                   TVS Apache RTR 180cc     Karnal      6639.0
# 60000.0               Bajaj Avenger Street 220      Delhi     20373.0
# 15600.0              Hero Super Splendor 125cc     Jaipur     84186.0
# 22000.0                     Bajaj Pulsar 150cc       Pune     60857.0
#
#                 owner   age  power          brand
# price
# 35000.0   First Owner   3.0  110.0            TVS
# ...

# %%
df.set_index('price',inplace = True)

# %%
df = df.sort_values('price')

# %%
df
# Out:
#                              bike_name       city  kms_driven         owner  \
# price
# 4400.0            LML Freedom DX 110cc    Godhara     55000.0   First Owner
# 5000.0             Hero Ambition 135cc      Delhi     82178.0   First Owner
# 5000.0             Hero Ambition 135cc      Delhi     82178.0   First Owner
# 5800.0                 TVS Flame 125cc  Ghaziabad     25000.0   First Owner
# 5800.0                 TVS Flame 125cc  Ghaziabad     25000.0   First Owner
# ...                                ...        ...         ...           ...
# 1500000.0           MV Agusta F3 800cc      Hubli      2000.0   First Owner
# 1500000.0           MV Agusta F3 800cc      Hubli      2000.0   First Owner
# 1550000.0         Yamaha YZF-R1 1000cc      Delhi      9800.0  Second Owner
# 1800000.0            BMW S 1000 RR Pro      Delhi      2600.0   First Owner
# 1900000.0  Indian Chief Classic 1800cc    Chennai      1700.0   First Owner
#
#             age   power   brand
# price
# ...

# %%
df.fillna(0)
# Out:
#                              bike_name       city  kms_driven         owner  \
# price
# 4400.0            LML Freedom DX 110cc    Godhara     55000.0   First Owner
# 5000.0             Hero Ambition 135cc      Delhi     82178.0   First Owner
# 5000.0             Hero Ambition 135cc      Delhi     82178.0   First Owner
# 5800.0                 TVS Flame 125cc  Ghaziabad     25000.0   First Owner
# 5800.0                 TVS Flame 125cc  Ghaziabad     25000.0   First Owner
# ...                                ...        ...         ...           ...
# 1500000.0           MV Agusta F3 800cc      Hubli      2000.0   First Owner
# 1500000.0           MV Agusta F3 800cc      Hubli      2000.0   First Owner
# 1550000.0         Yamaha YZF-R1 1000cc      Delhi      9800.0  Second Owner
# 1800000.0            BMW S 1000 RR Pro      Delhi      2600.0   First Owner
# 1900000.0  Indian Chief Classic 1800cc    Chennai      1700.0   First Owner
#
#             age   power   brand
# price
# ...

# %%
df1 = df.dropna()
df1
# Out:
#                              bike_name       city  kms_driven         owner  \
# price
# 4400.0            LML Freedom DX 110cc    Godhara     55000.0   First Owner
# 5000.0             Hero Ambition 135cc      Delhi     82178.0   First Owner
# 5000.0             Hero Ambition 135cc      Delhi     82178.0   First Owner
# 5800.0                 TVS Flame 125cc  Ghaziabad     25000.0   First Owner
# 5800.0                 TVS Flame 125cc  Ghaziabad     25000.0   First Owner
# ...                                ...        ...         ...           ...
# 1500000.0           MV Agusta F3 800cc      Hubli      2000.0   First Owner
# 1500000.0           MV Agusta F3 800cc      Hubli      2000.0   First Owner
# 1550000.0         Yamaha YZF-R1 1000cc      Delhi      9800.0  Second Owner
# 1800000.0            BMW S 1000 RR Pro      Delhi      2600.0   First Owner
# 1900000.0  Indian Chief Classic 1800cc    Chennai      1700.0   First Owner
#
#             age   power   brand
# price
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
plt.plot(x,y,'red')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("y=x**2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot([1,2,3],[4,5,6],'g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot([1,2,3,432,42.87])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
days = list(range(1,6))
celsius_min = [19,23,12,64,78]
celsius_max = [23,45,89,46,78]
plt.xlabel("Days")
plt.ylabel("temperatires  in celsus")
plt.plot(days,celsius_min,"oy",celsius_min, "-m",days,celsius_max,"or",days,celsius_max,"-g")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
x = np.linspace(0,2*np.pi,50)
f1 = np.sin

# %%
slices = [7,2,2,13]
activities = ["sleeping","eating","reading","playing"]
cols = ['c','m','b','g']
plt.pie = (slices,label = activities , colors = cols, startangle = 90, ecplode = [0,0.0,0,0.0])
plt.show
# Out:
#   File "<ipython-input-11-8867a54f1552>", line 4
#     plt.pie = (slices,label = activities , colors = cols, startangle = 90, ecplode = [0,0.0,0,0.0])
#                       ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
x=[1,2,3,4,5]
y = [3,4,5,6,6]
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#histogram

# %%
seaborn

# %%
import seaborn as sns
tips = sns.load_dataset("tips")

# %%
boxplot., heat map , line plot
